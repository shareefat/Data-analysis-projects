# %% [markdown]
# **IMPORTING DATASET**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('tracks.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
#  16  liveness          586672 non-null  float64
#  17  valence           586672 non-null  float64
#  18  tempo             586672 non-null  float64
#  19  time_signature    586672 non-null  int64
# dtypes: float64(9), int64(6), object(5)
# memory usage: 89.5+ MB

# %% [markdown]
# **Least 10 Popular Songs**

# %%
least_popular=df.sort_values(by='popularity').head(10)
print(least_popular['name'])
# Out:
# 546130         Newspaper Reports On Abner, 20 February 1935
# 546222                                               恋は水の上で
# 546221                                                私の誕生日
# 546220                                  エル・チョクロ (EL CHOCLO)
# 546219                                             恋は不思議なもの
# 546218                           ゆうべはどうしたの (WHATSA MALLA U)
# 546217    Screen Director's Playhouse, Music For Million...
# 546216                                               ブルーマンボ
# 546215    Screen Director's Playhouse, Trade Winds direc...
# 546214    Screen Director's Playhouse, It's A Wonderful ...
# Name: name, dtype: object

# %% [markdown]
# **Most 10 Popular Songs with popularity > 90**

# %%
most_popular=df[df['popularity']>90].sort_values(by='popularity',ascending=False).head(10)
print(most_popular['name'])
# Out:
# 93802    Peaches (feat. Daniel Caesar & Giveon)
# 93803                           drivers license
# 93804                    Astronaut In The Ocean
# 92810                           Save Your Tears
# 92811                                 telepatía
# 92813                           Blinding Lights
# 93805                       Leave The Door Open
# 92814                              The Business
# 91866                                   Streets
# 92816                    Heartbreak Anniversary
# Name: name, dtype: object

# %% [markdown]
# **Set release_date as Index**

# %%
df.set_index('release_date',inplace=True)
df.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922          08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922                   0       163080         0      ['Dick Haymes']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-02-22    ['45tIt06XoI0Iio4LBEVpls']         0.645  0.4450    0   -13.338
# 1922-06-01    ['14jtPCOoNZwquk5wd9DxrY']         0.695  0.2630    0   -22.136
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.434  0.1770    1   -21.180
# 1922-03-21    ['5LiOoJbxVSAMkBS2fUm3X2']         0.321  0.0946    7   -27.961
# 1922          ['3BiJGZsyX9sJchTqcSA7Su']         0.402  0.1580    3   -16.900
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-02-22       1       0.4510         0.674            0.7440     0.151
# 1922-06-01       1       0.9570         0.797            0.0000     0.148
# 1922-03-21       1       0.0512         0.994            0.0218     0.212
# 1922-03-21       1       0.0504         0.995            0.9180     0.104
# 1922             0       0.0390         0.989            0.1300     0.311
#
#               valence    tempo  time_signature
# release_date
# 1922-02-22      0.127  104.851               3
# 1922-06-01      0.655  102.009               1
# 1922-03-21      0.457  130.418               5
# 1922-03-21      0.397  169.980               3
# 1922            0.196  103.220               4

# %% [markdown]
# **Artist at 25th Row**

# %%
print(df.iloc[24]['artists'])
# Out:
# ['Fernando Pessoa']

# %% [markdown]
# **Converting Duration to Seconds**

# %%
df['duration_s']=df['duration_ms']/1000
df['duration_s'].head(5)
# Out:
# release_date
# 1922-02-22    126.903
# 1922-06-01     98.200
# 1922-03-21    181.640
# 1922-03-21    176.907
# 1922          163.080
# Name: duration_s, dtype: float64

# %% [markdown]
# **Correlation between features**

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %% [markdown]
# **Creating a sample data Frame**

# %%
sample_df=df.sample(frac=0.2)
sample_df.head()
# Out:
#               popularity  duration_ms  explicit  danceability  energy  key  \
# release_date
# 1938-05-02             0        90747         0         0.371   0.558    0
# 1959-05-13            18       222840         0         0.352   0.102    3
# 2009-02-18            34       195160         0         0.353   0.483    5
# 1991                  25       281840         0         0.349   0.563    7
# 2004-05-21            33       267413         0         0.432   0.285    5
#
#               loudness  mode  speechiness  acousticness  instrumentalness  \
# release_date
# 1938-05-02      -5.542     1       0.0576        0.9950          0.004390
# 1959-05-13     -16.865     1       0.0417        0.8990          0.000006
# 2009-02-18     -11.433     0       0.0575        0.2380          0.000000
# 1991           -11.644     1       0.0294        0.0198          0.000000
# 2004-05-21     -11.146     1       0.0364        0.6340          0.000003
#
#               liveness  valence    tempo  time_signature  duration_s  \
# release_date
# 1938-05-02      0.8830    0.426   95.968               1      90.747
# 1959-05-13      0.0834    0.245  174.400               3     222.840
# 2009-02-18      0.1140    0.398  110.546               4     195.160
# 1991            0.1530    0.280   87.879               4     281.840
# 2004-05-21      0.1760    0.552  104.112               4     267.413
#
#               artists_numeric
# release_date
# 1938-05-02              35763
# 1959-05-13               6783
# 2009-02-18              10488
# 1991                    33557
# 2004-05-21              73511

# %% [markdown]
# **Regression plot between loudness and energy**

# %%
sns.regplot(x='loudness',y='energy',data=df)
plt.show()

# %% [markdown]
# **Regression plot between Acousticness and Popularity**

# %%
sns.regplot(x='acousticness',y='popularity',data=df)
plt.show()
